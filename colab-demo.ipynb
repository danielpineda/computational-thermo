# %% [markdown]
# # Demo for using Colab
#
# You can use pip to install non-default packages like Cantera, Pint, and CoolProp:

# %%
# !pip install -q cantera pint coolprop

# %% [markdown]
# Now load all the necessary libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import cantera as ct

from pint import UnitRegistry
ureg = UnitRegistry()
Q_ = ureg.Quantity
